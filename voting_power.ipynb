# %%
import numpy as np
import matplotlib.pyplot as plt

def hauss_normal(x, mu, sigma):
    return (1 / (sigma * np.sqrt(2 * np.pi))) * np.exp(-(1/x)*((x - mu) ** (2)) / (2 * (sigma ** 2)))

mu = 2
sigma = 1

x = np.linspace(0.1, 5, 100)

y = hauss_normal(x, mu, sigma)

# Plot the distribution
plt.plot(x, y)
plt.title('Hauss Normal Distribution Modified')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def hauss_normal(x, mu, sigma):
    result = np.zeros(len(x))
    for i in len(x):
      while x[i] < mu:
        result[i] =  (1 / (sigma * np.sqrt(2 * np.pi))) * np.exp(-(1/x[i])*((x[i] - mu) ** (2)) / (2 * (sigma ** 2)))
      else:
      # return (1 / (sigma * np.sqrt(2 * np.pi))) * np.exp(-(1/x)*((x - mu) ** (2)) / (2 * (sigma ** 2)))
        return 1/(x*sigma)

mu = 2
sigma = 1

x = np.arange(0.1, 5, 0.01)

y = hauss_normal(x, mu, sigma)

# Plot the distribution
plt.plot(x, y)
plt.title('Hauss Normal Distribution Modified')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-993ceaece215> in <module>
#      16 x = np.arange(0.1, 5, 0.01)
#      17
# ---> 18 y = hauss_normal(x, mu, sigma)
#      19
#      20 # Plot the distribution
#
# <ipython-input-7-993ceaece215> in hauss_normal(x, mu, sigma)
#       4 def hauss_normal(x, mu, sigma):
#       5     result = np.zeros(len(x))
# ----> 6     for i in len(x):
#       7       while x[i] < mu:
#       8         result[i] =  (1 / (sigma * np.sqrt(2 * np.pi))) * np.exp(-(1/x[i])*((x[i] - mu) ** (2)) / (2 * (sigma ** 2)))
#
# TypeError: 'int' object is not iterable

# %%
import numpy as np
import matplotlib.pyplot as plt

def hauss_normal(x, mu, sigma):
    return (1 / (sigma * np.sqrt(2 * np.pi))) * np.exp(-((x - mu) ** (2)) / (2 * (sigma ** 2)))

mu = 2
sigma = 1

x = np.linspace(0, mu, 100)
k = np.linspace(0, 2, 100)

y = hauss_normal(x, mu, sigma)
y2 = np.linspace(y[len(y)-1], 0.4100000111111, 100)

plt.plot(x, y)
plt.plot(x2,y2)
plt.title('Voting power against tokens held')
plt.xlabel('FGT Token Held, thousands')
plt.ylabel('Voting Power')
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def hauss_normal(x, mu, sigma):
    return (1 / (sigma * np.sqrt(2 * np.pi))) * np.exp(-((x - mu) ** (2)) / (2 * (sigma ** 2)))

mu = 2
sigma = 1

x = np.linspace(0, 5, 100)

y = np.sqrt(x)
y2 = np.linspace(y[len(y)-1], 0.4100000111111, 100)

plt.plot(x, y)
plt.title('Voting power against tokens held')
plt.xlabel('FGT Token Held, thousands')
plt.ylabel('Voting Power')
plt.grid()
plt.show()
